# %%
# import keras
import shutil
import pandas as pd
import numpy as np
import os
# from tensorflow import keras
# import tensorflow as tf
# tf.compat.v1.disable_v2_behavior
os.chdir('C:\\Users\\umairansari\\Desktop\\identify dance\\dataset')

# %%
train_labels=pd.read_csv("train.csv")

# %%
train_labels["simple_name"]=train_labels["Image"].str.replace(".jpg","")
train_labels["ext"]=train_labels["Image"].str.split(".",expand=True)[1]
val=train_labels["target"].unique()
val=list(val)
for v in val:
    os.mkdir(v)
val
# Out:
# ['manipuri',
#  'bharatanatyam',
#  'odissi',
#  'kathakali',
#  'kathak',
#  'sattriya',
#  'kuchipudi',
#  'mohiniyattam']

# %%
train_labels["target"].value_counts()
# Out:
# mohiniyattam     50
# odissi           49
# kathakali        47
# bharatanatyam    47
# kuchipudi        46
# sattriya         45
# kathak           44
# manipuri         36
# Name: target, dtype: int64

# %%
manipuri=train_labels[train_labels["target"]=="manipuri"]
bharatanatyam=train_labels[train_labels["target"]=="bharatanatyam"]
odissi=train_labels[train_labels["target"]=="odissi"]
kathakali=train_labels[train_labels["target"]=="kathakali"]
kathak=train_labels[train_labels["target"]=="kathak"]
sattriya=train_labels[train_labels["target"]=="sattriya"]
kuchipudi=train_labels[train_labels["target"]=="kuchipudi"]
mohiniyattam=train_labels[train_labels["target"]=="mohiniyattam"]
# bharatanatyam=train_labels[train_labels["target"]=="bharatanatyam"]



#for mohiniyattam
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,mohiniyattam.shape[0]+1):
    x=mohiniyattam["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\mohiniyattam'
    shutil.copy(name,path )
    

#for kuchipudi
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,kuchipudi.shape[0]+1):
    x=kuchipudi["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\kuchipudi'
    shutil.copy(name,path )
    

#for sattriya
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,sattriya.shape[0]+1):
    x=sattriya["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\sattriya'
    shutil.copy(name,path )
    

#for kathak
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,kathak.shape[0]+1):
    x=kathak["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\kathak'
    shutil.copy(name,path )
    


#for kathakali
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,kathakali.shape[0]+1):
    x=kathakali["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\kathakali'
    shutil.copy(name,path )
    


#for odissi
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,odissi.shape[0]+1):
    x=odissi["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\odissi'
    shutil.copy(name,path )
    

#for bharatanatyam
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,bharatanatyam.shape[0]+1):
    x=bharatanatyam["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\bharatanatyam'
    shutil.copy(name,path )
    

#for manipuri
os.chdir("C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\train")
for i in range(1,manipuri.shape[0]+1):
    x=manipuri["simple_name"][i-1:i].values
    print(x[0])
    name=x[0]+".jpg"
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\manipuri'
    shutil.copy(name,path )

    
#renaming the files 
def name_rename(directory,name_of_files_to_append): 
    os.chdir(directory)
    for count, filename in enumerate(os.listdir(directory)): 
        dst =name_of_files_to_append + str(count) 
        src = filename 
        dst = dst+src 
        print(src+"  "+dst)
        os.rename(src, dst) 
        
for v in val:
    path='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset'+"\\"+v
    print(path)
    name_rename(directory=path,name_of_files_to_append=v)
# name_rename(directory='C:\\Users\\umairansari\\Desktop\\identify dance\\dataset\\manipuri',name_of_files_to_append="manipuri")
# Out:
# 248
# 255
# 274
# 294
# 259
# 296
# 265
# 277
# 299
# 303
# 309
# 276
# 254
# 272
# 252
# 261
# 279
# 262
# 308
# 244
# 289
# 298
# 273
# 312
# 267
# 293
# 297
# 288
# 245
# 247
# 263
# 295
# 287
# 249
# 305
# 304
# 258
# 266
# 310
# 257
# 282
# 251
# 300
# 307
# 268
# 250
# 281
# 260
# 253
# 311
# 408
# 422
# 397
# 400
# 376
# 388
# 384
# 387
# 393
# 423
# 406
# 407
# 395
# 377
# 405
# 443
# 379
# 425
# 436
# 409
# 434
# 383
# 412
# 418
# 442
# 389
# 427
# 430
# 426
# 417
# 428
# 413
# 402
# 381
# 399
# 382
# 403
# 433
# 432
# 420
# 415
# 391
# 396
# 435
# 419
# 404
# 326
# 365
# 350
# 333
# 347
# 348
# 335
# 321
# 344
# 343
# 361
# 331
# 370
# 367
# 371
# 353
# 329
# 345
# 372
# 313
# 325
# 322
# 314
# 356
# 336
# 342
# 334
# 357
# 315
# 359
# 319
# 364
# 320
# 369
# 328
# 352
# 339
# 327
# 362
# 337
# 355
# 338
# 341
# 368
# 351
# 46
# 32
# 39
# 47
# 16
# 2
# 19
# 24
# 4
# 21
# 15
# 56
# 29
# 30
# 18
# 3
# 12
# 26
# 22
# 25
# 27
# 31
# 58
# 42
# 54
# 60
# 37
# 49
# 7
# 44
# 50
# ...
